# %% [markdown]
# # Computation Graphs and Back Propagation

# %%
import numpy as np

# %% [markdown]
# ## Define a Set of Computation Nodes
#
# | Name        | Fomula           | Gradients  |
# |:-------------:|:------------- |:----- |
# | Linear      | $y=x^T\cdot W+b$ | $\frac{\partial \mathcal{L}}{x}=W\cdot\frac{\partial \mathcal{L}}{\partial y}\\\frac{\partial \mathcal{L}}{W}=x^T\cdot\frac{\partial \mathcal{L}}{\partial y}\\\frac{\partial \mathcal{L}}{b}=\frac{\partial \mathcal{L}}{\partial y}$ |
# | Sigmoid     | $y=\frac{1}{1+e^{-x}}$  | $\frac{\partial \mathcal{L}}{x}=\frac{\partial \mathcal{L}}{\partial y}(1-y)y$ |
# | Softmax     | $y_j=\frac{e^{x_j}}{\sum\limits_i e^{x_i}}$ | $\frac{\partial \mathcal{L}}{x_j}=\frac{\partial \mathcal{L}}{\partial y_j}y_j-y_j\sum\limits_i \frac{\partial \mathcal{L}}{\partial y_i}y_i$ |
# | CrossEntropy | $y=-\sum\limits_i p_i \log(x_i)$ | $\frac{\partial \mathcal{L}}{x_i}=-\frac{\partial \mathcal{L}}{\partial y}\frac{p_i}{x_i}$ |
# | Mean  | $y=\frac{1}{N}\sum\limits_i x_i$ | $\frac{\partial \mathcal{L}}{x_i}=\frac{1}{N}\frac{\partial \mathcal{L}}{\partial y}$ |
#
#
# ### Linear: $y=x^T\cdot W+b, \frac{\partial \mathcal{L}}{x}=W\cdot\frac{\partial \mathcal{L}}{\partial y},\frac{\partial \mathcal{L}}{W}=x^T\cdot\frac{\partial \mathcal{L}}{\partial y},\frac{\partial \mathcal{L}}{b}=\frac{\partial \mathcal{L}}{\partial y}$
# ### Sigmoid: $y=\frac{1}{1+e^{-x}}, \frac{\partial \mathcal{L}}{x}=\frac{\partial \mathcal{L}}{\partial y}(1-y)y$
# ### Softmax: $y_j=\frac{e^{x_j}}{\sum\limits_i e^{x_i}},\frac{\partial \mathcal{L}}{x_j}=\frac{\partial \mathcal{L}}{\partial y_j}y_j-y_j\sum\limits_i \frac{\partial \mathcal{L}}{\partial y_i}y_i$
# ### CrossEntropy: $y=-\sum\limits_i p_i \log(x_i),\frac{\partial \mathcal{L}}{x_i}=-\frac{\partial \mathcal{L}}{\partial y}\frac{p_i}{x_i}$
# ### Mean: $y=\frac{1}{N}\sum\limits_i x_i,\frac{\partial \mathcal{L}}{x_i}=\frac{1}{N}\frac{\partial \mathcal{L}}{\partial y}$

# %%
class Linear(object):
    def __init__(self, input_shape, output_shape, mean=0, variance=0.1):
        self.parameters = [mean + variance * np.random.randn(input_shape, output_shape),
                           mean + variance * np.random.randn(output_shape)]
        self.parameters_deltas = [None, None]

    def forward(self, x, *args):
        self.x = x
        return np.matmul(x, self.parameters[0]) + self.parameters[1]

    def backward(self, delta):
        self.parameters_deltas[0] = self.x.T.dot(delta)
        self.parameters_deltas[1] = np.sum(delta, 0)
        return delta.dot(self.parameters[0].T)


class F(object):
    '''base class for functions with no parameters.'''

    def __init__(self):
        self.parameters = []
        self.parameters_deltas = []


class Sigmoid(F):
    def forward(self, x, *args):
        self.x = x
        self.y = 1.0 / (1.0 + np.exp(-x))
        return self.y

    def backward(self, delta):
        return delta * ((1 - self.y) * self.y)


class Softmax(F):
    def forward(self, x, *args):
        self.x = x
        xtmp = x - x.max(axis=-1, keepdims=True)
        exps = np.exp(xtmp)
        self.y = exps / exps.sum(axis=-1, keepdims=True)
        return self.y

    def backward(self, delta):
        return delta * self.y - self.y * (delta * self.y).sum(axis=-1, keepdims=True)


class CrossEntropy(F):
    def forward(self, x, p, *args):
        self.p = p
        self.x = x
        y = -p * np.log(np.maximum(x, 1e-15))
        return y.sum(-1)

    def backward(self, delta):
        return -delta[..., None] * 1. / np.maximum(self.x, 1e-15) * self.p


class Mean(F):
    def forward(self, x, *args):
        self.x = x
        return x.mean()

    def backward(self, delta):
        return delta * np.ones(self.x.shape) / np.prod(self.x.shape)

# %% [markdown]
# ## Sanity Check

# %%
def numdiff(layer, x, var, y_delta, delta, args):
    '''numerical differenciation.'''
    var_raveled = var.ravel()

    var_delta_list = []
    for ix in range(len(var_raveled)):
        var_raveled[ix] += delta / 2.
        yplus = layer.forward(x, *args)
        var_raveled[ix] -= delta
        yminus = layer.forward(x, *args)
        var_delta = ((yplus - yminus) / delta * y_delta).sum()
        var_delta_list.append(var_delta)

        # restore changes
        var_raveled[ix] += delta / 2.
    return np.array(var_delta_list)


def sanity_check(layer, x, args=(), delta=0.01, precision=1e-3):
    '''
    perform sanity check for a layer,
    raise an assertion error if failed to pass all sanity checks.

    Args:
        layer (obj): user defined neural network layer.
        x (ndarray): input array.
        args: additional arguments for forward function.
        delta: the strength of perturbation used in numdiff.
        precision: the required precision of gradient (usually introduced by numdiff).
    '''
    y = layer.forward(x, *args)
    # y_delta is the gradient passed from the next layer, i.e. dL/dy.
    y_delta = np.random.randn(*y.shape)
    x_delta = layer.backward(y_delta)

    for var, var_delta in zip([x] + layer.parameters, [x_delta] + layer.parameters_deltas):
        var_delta_num = numdiff(layer, x, var, y_delta, delta, args)
        np.testing.assert_allclose(var_delta_num.reshape(
            *var_delta.shape), var_delta, atol=precision, rtol=precision)

# %%
for layer in [Linear(6, 4), Sigmoid(), Softmax(), Mean()]:
    print('checking %s' % layer.__class__.__name__)
    x = np.random.uniform(size=(5, 6))
    sanity_check(layer, x)

# we take special care of cross entropy layer here,
# it takes an additional parameter l
layer = CrossEntropy()
print('checking %s' % layer.__class__.__name__)
p = np.random.uniform(0.1, 1, [5, 6])
p = p / p.sum(axis=-1, keepdims=True)
x = np.random.uniform(0.1, 1, [5, 6])
x = x / x.sum(axis=-1, keepdims=True)
sanity_check(layer, x, args=(p,), precision=1e-1)
# Out:
# checking Linear
# checking Sigmoid
# checking Softmax
# checking Mean
# checking CrossEntropy

# %%
import subprocess
import os
import struct


def load_MNIST():
    base = "http://yann.lecun.com/exdb/mnist/"
    objects = ['t10k-images-idx3-ubyte', 't10k-labels-idx1-ubyte',
               'train-images-idx3-ubyte', 'train-labels-idx1-ubyte']
    end = ".gz"
    path = "../data/raw/"
    cmd = ["mkdir", "-p", path]
    subprocess.check_call(cmd)
    for obj in objects:
        if not os.path.isfile(path + obj):
            cmd = ["wget", base + obj + end, "-P", path]
            subprocess.check_call(cmd)
            cmd = ["gzip", "-d", path + obj + end]
            subprocess.check_call(cmd)

    def unpack(filename):
        '''unpack a single file.'''
        with open(filename, 'rb') as f:
            _, _, dims = struct.unpack('>HBB', f.read(4))
            shape = tuple(struct.unpack('>I', f.read(4))
                          [0] for d in range(dims))
            data = np.fromstring(f.read(), dtype=np.uint8).reshape(shape)
            return data

    # load objects
    data = []
    for name in objects:
        name = path + name
        data.append(unpack(name))
    labels = np.zeros([data[1].shape[0], 10])
    for i, iterm in enumerate(data[1]):
        labels[i][iterm] = 1
    data[1] = labels
    labels = np.zeros([data[3].shape[0], 10])
    for i, iterm in enumerate(data[3]):
        labels[i][iterm] = 1
    data[3] = labels
    return data

# %%
def random_draw(data, label, batch_size):
    perm = np.random.permutation(data.shape[0])
    data_b = data[perm[:batch_size]]
    label_b = label[perm[:batch_size]]
    return data_b.reshape([data_b.shape[0], -1]) / 255.0, label_b

# %%
np.random.seed(5)
batchsize = 100
learning_rate = 0.5
dim_img = 784
num_digit = 10
num_epoch = 10
train_data, train_label, test_data, test_label = load_MNIST()
num_iteration = len(train_data) // batchsize * num_epoch


def match_ratio(result, label):
    '''the match rate between result and label'''
    label_p = np.argmax(result, axis=1)
    label_t = np.argmax(label, axis=1)
    ratio = np.sum(label_p == label_t) / label_t.shape[0]
    return ratio


lossfunc = CrossEntropy()
layers = [Linear(dim_img, num_digit), Softmax(), lossfunc, Mean()]


def net_forward(x, label):
    for layer in layers:
        if layer is lossfunc:
            result = x
            x = layer.forward(x, label)
        else:
            x = layer.forward(x)
    return result, x


def net_backward(y_delta):
    for layer in layers[::-1]:
        y_delta = layer.backward(y_delta)
    return y_delta


for j in range(num_iteration):
    x, label = random_draw(train_data, train_label, batchsize)
    result, loss = net_forward(x, label)
    print("iteration = %d/%d, loss = %.4f, ratio = %.2f" %
          (j, num_iteration, loss, match_ratio(result, label)))

    net_backward(learning_rate)

    # update network parameters
    for layer in layers:
        for p, p_delta in zip(layer.parameters, layer.parameters_deltas):
            p -= p_delta  # stochastic gradient descent

x, label = random_draw(test_data, test_label, 1000)
result, loss = net_forward(x, label)
print('Test loss = %.4f, ratio = %.3f' % (loss, match_ratio(result, label)))
# Out:
# iteration = 0/1000, loss = 3.0850, ratio = 0.13
# iteration = 1/1000, loss = 2.6967, ratio = 0.21
# iteration = 2/1000, loss = 2.0212, ratio = 0.31
# iteration = 3/1000, loss = 1.7928, ratio = 0.38
# iteration = 4/1000, loss = 1.4996, ratio = 0.49
# iteration = 5/1000, loss = 1.4240, ratio = 0.47
# iteration = 6/1000, loss = 1.3433, ratio = 0.60
# iteration = 7/1000, loss = 1.1618, ratio = 0.63
# iteration = 8/1000, loss = 0.9574, ratio = 0.67
# iteration = 9/1000, loss = 0.7831, ratio = 0.76
# iteration = 10/1000, loss = 0.7865, ratio = 0.75
# iteration = 11/1000, loss = 0.7722, ratio = 0.80
# iteration = 12/1000, loss = 0.8128, ratio = 0.78
# iteration = 13/1000, loss = 0.8264, ratio = 0.72
# iteration = 14/1000, loss = 0.6225, ratio = 0.82
# iteration = 15/1000, loss = 0.7114, ratio = 0.85
# iteration = 16/1000, loss = 0.6563, ratio = 0.82
# iteration = 17/1000, loss = 0.7819, ratio = 0.78
# iteration = 18/1000, loss = 0.6334, ratio = 0.84
# iteration = 19/1000, loss = 0.5958, ratio = 0.86
# iteration = 20/1000, loss = 0.7414, ratio = 0.74
# iteration = 21/1000, loss = 0.5786, ratio = 0.83
# iteration = 22/1000, loss = 0.8235, ratio = 0.76
# iteration = 23/1000, loss = 0.7066, ratio = 0.80
# iteration = 24/1000, loss = 0.6228, ratio = 0.82
# iteration = 25/1000, loss = 0.6105, ratio = 0.79
# iteration = 26/1000, loss = 0.6224, ratio = 0.82
# iteration = 27/1000, loss = 0.5433, ratio = 0.80
# iteration = 28/1000, loss = 0.6476, ratio = 0.83
# iteration = 29/1000, loss = 0.3922, ratio = 0.93
# iteration = 30/1000, loss = 0.6537, ratio = 0.80
# iteration = 31/1000, loss = 0.4276, ratio = 0.89
# iteration = 32/1000, loss = 0.5030, ratio = 0.88
# iteration = 33/1000, loss = 0.5423, ratio = 0.86
# iteration = 34/1000, loss = 0.5822, ratio = 0.84
# iteration = 35/1000, loss = 0.5737, ratio = 0.80
# iteration = 36/1000, loss = 0.4779, ratio = 0.87
# iteration = 37/1000, loss = 0.4938, ratio = 0.89
# iteration = 38/1000, loss = 0.5148, ratio = 0.82
# iteration = 39/1000, loss = 0.5827, ratio = 0.84
# iteration = 40/1000, loss = 0.4795, ratio = 0.85
# iteration = 41/1000, loss = 0.3848, ratio = 0.92
# iteration = 42/1000, loss = 0.4582, ratio = 0.84
# iteration = 43/1000, loss = 0.4445, ratio = 0.88
# iteration = 44/1000, loss = 0.4152, ratio = 0.88
# iteration = 45/1000, loss = 0.5103, ratio = 0.84
# iteration = 46/1000, loss = 0.4795, ratio = 0.86
# iteration = 47/1000, loss = 0.8139, ratio = 0.79
# iteration = 48/1000, loss = 0.5332, ratio = 0.81
# iteration = 49/1000, loss = 0.4293, ratio = 0.91
# iteration = 50/1000, loss = 0.4250, ratio = 0.87
# iteration = 51/1000, loss = 0.4461, ratio = 0.87
# iteration = 52/1000, loss = 0.4073, ratio = 0.92
# iteration = 53/1000, loss = 0.3658, ratio = 0.92
# iteration = 54/1000, loss = 0.3756, ratio = 0.93
# iteration = 55/1000, loss = 0.4001, ratio = 0.89
# iteration = 56/1000, loss = 0.5032, ratio = 0.87
# iteration = 57/1000, loss = 0.4265, ratio = 0.89
# iteration = 58/1000, loss = 0.4387, ratio = 0.86
# iteration = 59/1000, loss = 0.3609, ratio = 0.89
# iteration = 60/1000, loss = 0.4561, ratio = 0.89
# iteration = 61/1000, loss = 0.3729, ratio = 0.90
# iteration = 62/1000, loss = 0.4394, ratio = 0.84
# iteration = 63/1000, loss = 0.4450, ratio = 0.91
# iteration = 64/1000, loss = 0.4739, ratio = 0.86
# iteration = 65/1000, loss = 0.3768, ratio = 0.87
# iteration = 66/1000, loss = 0.4522, ratio = 0.85
# iteration = 67/1000, loss = 0.4570, ratio = 0.87
# iteration = 68/1000, loss = 0.3846, ratio = 0.95
# iteration = 69/1000, loss = 0.2869, ratio = 0.91
# iteration = 70/1000, loss = 0.4641, ratio = 0.86
# iteration = 71/1000, loss = 0.3113, ratio = 0.90
# iteration = 72/1000, loss = 0.2348, ratio = 0.97
# iteration = 73/1000, loss = 0.3750, ratio = 0.87
# iteration = 74/1000, loss = 0.3305, ratio = 0.93
# iteration = 75/1000, loss = 0.5965, ratio = 0.83
# iteration = 76/1000, loss = 0.3260, ratio = 0.89
# iteration = 77/1000, loss = 0.4177, ratio = 0.88
# iteration = 78/1000, loss = 0.3441, ratio = 0.90
# iteration = 79/1000, loss = 0.3654, ratio = 0.91
# iteration = 80/1000, loss = 0.4678, ratio = 0.90
# iteration = 81/1000, loss = 0.2549, ratio = 0.94
# iteration = 82/1000, loss = 0.5398, ratio = 0.85
# iteration = 83/1000, loss = 0.4873, ratio = 0.85
# iteration = 84/1000, loss = 0.3836, ratio = 0.91
# iteration = 85/1000, loss = 0.3218, ratio = 0.91
# iteration = 86/1000, loss = 0.4026, ratio = 0.88
# iteration = 87/1000, loss = 0.3930, ratio = 0.90
# iteration = 88/1000, loss = 0.3857, ratio = 0.86
# iteration = 89/1000, loss = 0.3476, ratio = 0.91
# iteration = 90/1000, loss = 0.4487, ratio = 0.92
# iteration = 91/1000, loss = 0.2500, ratio = 0.94
# iteration = 92/1000, loss = 0.3832, ratio = 0.89
# iteration = 93/1000, loss = 0.3909, ratio = 0.88
# iteration = 94/1000, loss = 0.4624, ratio = 0.86
# iteration = 95/1000, loss = 0.5011, ratio = 0.85
# iteration = 96/1000, loss = 0.2833, ratio = 0.91
# iteration = 97/1000, loss = 0.2664, ratio = 0.95
# iteration = 98/1000, loss = 0.3955, ratio = 0.90
# iteration = 99/1000, loss = 0.2712, ratio = 0.94
# iteration = 100/1000, loss = 0.4686, ratio = 0.81
# iteration = 101/1000, loss = 0.3611, ratio = 0.90
# iteration = 102/1000, loss = 0.4169, ratio = 0.86
# iteration = 103/1000, loss = 0.3568, ratio = 0.90
# iteration = 104/1000, loss = 0.4497, ratio = 0.85
# iteration = 105/1000, loss = 0.3251, ratio = 0.90
# iteration = 106/1000, loss = 0.4202, ratio = 0.88
# iteration = 107/1000, loss = 0.3920, ratio = 0.89
# iteration = 108/1000, loss = 0.4062, ratio = 0.86
# iteration = 109/1000, loss = 0.4589, ratio = 0.87
# iteration = 110/1000, loss = 0.4930, ratio = 0.89
# iteration = 111/1000, loss = 0.4232, ratio = 0.88
# iteration = 112/1000, loss = 0.3284, ratio = 0.91
# iteration = 113/1000, loss = 0.4412, ratio = 0.88
# iteration = 114/1000, loss = 0.3656, ratio = 0.87
# iteration = 115/1000, loss = 0.3906, ratio = 0.86
# iteration = 116/1000, loss = 0.3218, ratio = 0.90
# iteration = 117/1000, loss = 0.3690, ratio = 0.87
# iteration = 118/1000, loss = 0.3338, ratio = 0.90
# iteration = 119/1000, loss = 0.3184, ratio = 0.91
# iteration = 120/1000, loss = 0.3969, ratio = 0.90
# iteration = 121/1000, loss = 0.2556, ratio = 0.94
# iteration = 122/1000, loss = 0.3358, ratio = 0.90
# iteration = 123/1000, loss = 0.3625, ratio = 0.94
# iteration = 124/1000, loss = 0.3868, ratio = 0.93
# iteration = 125/1000, loss = 0.2527, ratio = 0.93
# iteration = 126/1000, loss = 0.3101, ratio = 0.92
# iteration = 127/1000, loss = 0.3731, ratio = 0.89
# iteration = 128/1000, loss = 0.3354, ratio = 0.93
# iteration = 129/1000, loss = 0.3707, ratio = 0.89
# iteration = 130/1000, loss = 0.3318, ratio = 0.91
# iteration = 131/1000, loss = 0.3796, ratio = 0.89
# iteration = 132/1000, loss = 0.4860, ratio = 0.86
# iteration = 133/1000, loss = 0.2762, ratio = 0.91
# iteration = 134/1000, loss = 0.2554, ratio = 0.91
# iteration = 135/1000, loss = 0.3612, ratio = 0.86
# iteration = 136/1000, loss = 0.3498, ratio = 0.88
# iteration = 137/1000, loss = 0.3313, ratio = 0.89
# iteration = 138/1000, loss = 0.2557, ratio = 0.94
# iteration = 139/1000, loss = 0.4364, ratio = 0.86
# iteration = 140/1000, loss = 0.2467, ratio = 0.94
# iteration = 141/1000, loss = 0.3332, ratio = 0.91
# iteration = 142/1000, loss = 0.3160, ratio = 0.86
# iteration = 143/1000, loss = 0.3865, ratio = 0.86
# iteration = 144/1000, loss = 0.3963, ratio = 0.90
# iteration = 145/1000, loss = 0.3518, ratio = 0.91
# iteration = 146/1000, loss = 0.3761, ratio = 0.87
# iteration = 147/1000, loss = 0.4226, ratio = 0.90
# iteration = 148/1000, loss = 0.3290, ratio = 0.88
# iteration = 149/1000, loss = 0.3111, ratio = 0.92
# iteration = 150/1000, loss = 0.3586, ratio = 0.89
# iteration = 151/1000, loss = 0.3295, ratio = 0.93
# iteration = 152/1000, loss = 0.3623, ratio = 0.86
# iteration = 153/1000, loss = 0.3851, ratio = 0.91
# iteration = 154/1000, loss = 0.3628, ratio = 0.88
# iteration = 155/1000, loss = 0.3953, ratio = 0.92
# iteration = 156/1000, loss = 0.2656, ratio = 0.92
# iteration = 157/1000, loss = 0.2283, ratio = 0.94
# iteration = 158/1000, loss = 0.3272, ratio = 0.91
# iteration = 159/1000, loss = 0.2847, ratio = 0.90
# iteration = 160/1000, loss = 0.3251, ratio = 0.92
# iteration = 161/1000, loss = 0.3509, ratio = 0.87
# iteration = 162/1000, loss = 0.3253, ratio = 0.90
# iteration = 163/1000, loss = 0.2809, ratio = 0.92
# iteration = 164/1000, loss = 0.3027, ratio = 0.88
# iteration = 165/1000, loss = 0.3540, ratio = 0.87
# iteration = 166/1000, loss = 0.3904, ratio = 0.89
# iteration = 167/1000, loss = 0.2539, ratio = 0.96
# iteration = 168/1000, loss = 0.2994, ratio = 0.93
# iteration = 169/1000, loss = 0.2590, ratio = 0.91
# iteration = 170/1000, loss = 0.3313, ratio = 0.91
# iteration = 171/1000, loss = 0.3028, ratio = 0.91
# iteration = 172/1000, loss = 0.2531, ratio = 0.93
# iteration = 173/1000, loss = 0.2538, ratio = 0.92
# iteration = 174/1000, loss = 0.4595, ratio = 0.84
# iteration = 175/1000, loss = 0.3949, ratio = 0.91
# iteration = 176/1000, loss = 0.4774, ratio = 0.85
# iteration = 177/1000, loss = 0.3593, ratio = 0.87
# iteration = 178/1000, loss = 0.3140, ratio = 0.94
# iteration = 179/1000, loss = 0.2576, ratio = 0.92
# iteration = 180/1000, loss = 0.2770, ratio = 0.93
# iteration = 181/1000, loss = 0.3904, ratio = 0.92
# iteration = 182/1000, loss = 0.4701, ratio = 0.88
# iteration = 183/1000, loss = 0.2794, ratio = 0.90
# iteration = 184/1000, loss = 0.2387, ratio = 0.94
# iteration = 185/1000, loss = 0.2841, ratio = 0.95
# iteration = 186/1000, loss = 0.2647, ratio = 0.93
# iteration = 187/1000, loss = 0.3050, ratio = 0.91
# iteration = 188/1000, loss = 0.4389, ratio = 0.90
# iteration = 189/1000, loss = 0.4103, ratio = 0.87
# iteration = 190/1000, loss = 0.2372, ratio = 0.92
# iteration = 191/1000, loss = 0.3657, ratio = 0.93
# iteration = 192/1000, loss = 0.4270, ratio = 0.88
# iteration = 193/1000, loss = 0.3422, ratio = 0.90
# iteration = 194/1000, loss = 0.3632, ratio = 0.94
# iteration = 195/1000, loss = 0.3011, ratio = 0.91
# iteration = 196/1000, loss = 0.3338, ratio = 0.91
# iteration = 197/1000, loss = 0.4147, ratio = 0.92
# iteration = 198/1000, loss = 0.3519, ratio = 0.91
# iteration = 199/1000, loss = 0.2890, ratio = 0.92
# iteration = 200/1000, loss = 0.2278, ratio = 0.92
# iteration = 201/1000, loss = 0.3304, ratio = 0.90
# iteration = 202/1000, loss = 0.3636, ratio = 0.93
# iteration = 203/1000, loss = 0.4554, ratio = 0.87
# iteration = 204/1000, loss = 0.2296, ratio = 0.96
# iteration = 205/1000, loss = 0.2752, ratio = 0.94
# iteration = 206/1000, loss = 0.4624, ratio = 0.88
# iteration = 207/1000, loss = 0.2911, ratio = 0.90
# iteration = 208/1000, loss = 0.3767, ratio = 0.88
# iteration = 209/1000, loss = 0.2303, ratio = 0.96
# iteration = 210/1000, loss = 0.3294, ratio = 0.90
# iteration = 211/1000, loss = 0.2598, ratio = 0.93
# iteration = 212/1000, loss = 0.4205, ratio = 0.88
# iteration = 213/1000, loss = 0.2353, ratio = 0.93
# iteration = 214/1000, loss = 0.2862, ratio = 0.95
# iteration = 215/1000, loss = 0.3029, ratio = 0.94
# iteration = 216/1000, loss = 0.2486, ratio = 0.92
# iteration = 217/1000, loss = 0.2493, ratio = 0.93
# iteration = 218/1000, loss = 0.3476, ratio = 0.91
# iteration = 219/1000, loss = 0.2217, ratio = 0.93
# iteration = 220/1000, loss = 0.3666, ratio = 0.87
# iteration = 221/1000, loss = 0.3231, ratio = 0.90
# iteration = 222/1000, loss = 0.3574, ratio = 0.89
# iteration = 223/1000, loss = 0.3167, ratio = 0.89
# iteration = 224/1000, loss = 0.3364, ratio = 0.94
# iteration = 225/1000, loss = 0.2408, ratio = 0.92
# iteration = 226/1000, loss = 0.2380, ratio = 0.95
# iteration = 227/1000, loss = 0.2573, ratio = 0.95
# iteration = 228/1000, loss = 0.2788, ratio = 0.91
# iteration = 229/1000, loss = 0.1959, ratio = 0.95
# iteration = 230/1000, loss = 0.3280, ratio = 0.87
# iteration = 231/1000, loss = 0.3508, ratio = 0.90
# iteration = 232/1000, loss = 0.3418, ratio = 0.88
# iteration = 233/1000, loss = 0.3993, ratio = 0.85
# iteration = 234/1000, loss = 0.2474, ratio = 0.94
# iteration = 235/1000, loss = 0.2577, ratio = 0.94
# iteration = 236/1000, loss = 0.3727, ratio = 0.88
# iteration = 237/1000, loss = 0.4117, ratio = 0.89
# iteration = 238/1000, loss = 0.2890, ratio = 0.92
# iteration = 239/1000, loss = 0.4232, ratio = 0.90
# iteration = 240/1000, loss = 0.3332, ratio = 0.88
# iteration = 241/1000, loss = 0.2892, ratio = 0.91
# iteration = 242/1000, loss = 0.2659, ratio = 0.92
# iteration = 243/1000, loss = 0.4698, ratio = 0.86
# iteration = 244/1000, loss = 0.2636, ratio = 0.93
# iteration = 245/1000, loss = 0.3722, ratio = 0.91
# iteration = 246/1000, loss = 0.3997, ratio = 0.86
# iteration = 247/1000, loss = 0.2006, ratio = 0.94
# iteration = 248/1000, loss = 0.2389, ratio = 0.93
# iteration = 249/1000, loss = 0.3297, ratio = 0.87
# iteration = 250/1000, loss = 0.2832, ratio = 0.93
# iteration = 251/1000, loss = 0.2309, ratio = 0.94
# iteration = 252/1000, loss = 0.3436, ratio = 0.91
# iteration = 253/1000, loss = 0.2465, ratio = 0.94
# iteration = 254/1000, loss = 0.2606, ratio = 0.91
# iteration = 255/1000, loss = 0.2485, ratio = 0.93
# iteration = 256/1000, loss = 0.2567, ratio = 0.94
# iteration = 257/1000, loss = 0.2688, ratio = 0.94
# iteration = 258/1000, loss = 0.2521, ratio = 0.92
# iteration = 259/1000, loss = 0.2210, ratio = 0.97
# iteration = 260/1000, loss = 0.2976, ratio = 0.93
# iteration = 261/1000, loss = 0.3337, ratio = 0.91
# iteration = 262/1000, loss = 0.1905, ratio = 0.96
# iteration = 263/1000, loss = 0.4278, ratio = 0.86
# iteration = 264/1000, loss = 0.4330, ratio = 0.88
# iteration = 265/1000, loss = 0.3648, ratio = 0.88
# iteration = 266/1000, loss = 0.3141, ratio = 0.90
# iteration = 267/1000, loss = 0.3138, ratio = 0.92
# iteration = 268/1000, loss = 0.3356, ratio = 0.89
# iteration = 269/1000, loss = 0.2395, ratio = 0.95
# iteration = 270/1000, loss = 0.2878, ratio = 0.94
# iteration = 271/1000, loss = 0.2949, ratio = 0.88
# iteration = 272/1000, loss = 0.2607, ratio = 0.92
# iteration = 273/1000, loss = 0.3211, ratio = 0.89
# iteration = 274/1000, loss = 0.2357, ratio = 0.94
# iteration = 275/1000, loss = 0.3662, ratio = 0.90
# iteration = 276/1000, loss = 0.3043, ratio = 0.88
# iteration = 277/1000, loss = 0.2680, ratio = 0.89
# iteration = 278/1000, loss = 0.3842, ratio = 0.88
# iteration = 279/1000, loss = 0.3436, ratio = 0.89
# iteration = 280/1000, loss = 0.3661, ratio = 0.85
# iteration = 281/1000, loss = 0.2325, ratio = 0.91
# iteration = 282/1000, loss = 0.2117, ratio = 0.93
# iteration = 283/1000, loss = 0.2918, ratio = 0.94
# iteration = 284/1000, loss = 0.3225, ratio = 0.90
# iteration = 285/1000, loss = 0.3299, ratio = 0.88
# iteration = 286/1000, loss = 0.4471, ratio = 0.90
# iteration = 287/1000, loss = 0.2515, ratio = 0.92
# iteration = 288/1000, loss = 0.2998, ratio = 0.94
# iteration = 289/1000, loss = 0.1804, ratio = 0.95
# iteration = 290/1000, loss = 0.2986, ratio = 0.91
# iteration = 291/1000, loss = 0.1681, ratio = 0.95
# iteration = 292/1000, loss = 0.3352, ratio = 0.93
# iteration = 293/1000, loss = 0.1946, ratio = 0.94
# iteration = 294/1000, loss = 0.3708, ratio = 0.91
# iteration = 295/1000, loss = 0.1938, ratio = 0.95
# iteration = 296/1000, loss = 0.2738, ratio = 0.93
# iteration = 297/1000, loss = 0.3330, ratio = 0.90
# iteration = 298/1000, loss = 0.4146, ratio = 0.89
# iteration = 299/1000, loss = 0.2829, ratio = 0.93
# iteration = 300/1000, loss = 0.2701, ratio = 0.91
# iteration = 301/1000, loss = 0.2082, ratio = 0.96
# iteration = 302/1000, loss = 0.2662, ratio = 0.89
# iteration = 303/1000, loss = 0.2547, ratio = 0.93
# iteration = 304/1000, loss = 0.3466, ratio = 0.91
# iteration = 305/1000, loss = 0.3460, ratio = 0.87
# iteration = 306/1000, loss = 0.3129, ratio = 0.90
# iteration = 307/1000, loss = 0.2600, ratio = 0.93
# iteration = 308/1000, loss = 0.2467, ratio = 0.94
# iteration = 309/1000, loss = 0.3080, ratio = 0.91
# iteration = 310/1000, loss = 0.2380, ratio = 0.93
# iteration = 311/1000, loss = 0.1680, ratio = 0.95
# iteration = 312/1000, loss = 0.5398, ratio = 0.85
# iteration = 313/1000, loss = 0.2472, ratio = 0.92
# iteration = 314/1000, loss = 0.2205, ratio = 0.93
# iteration = 315/1000, loss = 0.2779, ratio = 0.92
# iteration = 316/1000, loss = 0.2219, ratio = 0.95
# iteration = 317/1000, loss = 0.2428, ratio = 0.94
# iteration = 318/1000, loss = 0.2471, ratio = 0.91
# iteration = 319/1000, loss = 0.1990, ratio = 0.96
# iteration = 320/1000, loss = 0.2004, ratio = 0.93
# iteration = 321/1000, loss = 0.2730, ratio = 0.92
# iteration = 322/1000, loss = 0.2334, ratio = 0.91
# iteration = 323/1000, loss = 0.3129, ratio = 0.91
# iteration = 324/1000, loss = 0.2508, ratio = 0.93
# iteration = 325/1000, loss = 0.3358, ratio = 0.93
# iteration = 326/1000, loss = 0.1615, ratio = 0.96
# iteration = 327/1000, loss = 0.3054, ratio = 0.87
# iteration = 328/1000, loss = 0.2049, ratio = 0.94
# iteration = 329/1000, loss = 0.1883, ratio = 0.95
# iteration = 330/1000, loss = 0.2085, ratio = 0.94
# iteration = 331/1000, loss = 0.3614, ratio = 0.88
# iteration = 332/1000, loss = 0.3907, ratio = 0.86
# iteration = 333/1000, loss = 0.2340, ratio = 0.94
# iteration = 334/1000, loss = 0.1398, ratio = 0.99
# iteration = 335/1000, loss = 0.1796, ratio = 0.97
# iteration = 336/1000, loss = 0.2362, ratio = 0.93
# iteration = 337/1000, loss = 0.2360, ratio = 0.93
# iteration = 338/1000, loss = 0.2047, ratio = 0.94
# iteration = 339/1000, loss = 0.2676, ratio = 0.91
# iteration = 340/1000, loss = 0.4311, ratio = 0.86
# iteration = 341/1000, loss = 0.3041, ratio = 0.91
# iteration = 342/1000, loss = 0.3572, ratio = 0.90
# iteration = 343/1000, loss = 0.1783, ratio = 0.94
# iteration = 344/1000, loss = 0.2385, ratio = 0.96
# iteration = 345/1000, loss = 0.2928, ratio = 0.89
# iteration = 346/1000, loss = 0.2002, ratio = 0.95
# iteration = 347/1000, loss = 0.2924, ratio = 0.93
# iteration = 348/1000, loss = 0.2759, ratio = 0.90
# iteration = 349/1000, loss = 0.2723, ratio = 0.94
# iteration = 350/1000, loss = 0.2495, ratio = 0.91
# iteration = 351/1000, loss = 0.2384, ratio = 0.91
# iteration = 352/1000, loss = 0.1651, ratio = 0.96
# iteration = 353/1000, loss = 0.2466, ratio = 0.94
# iteration = 354/1000, loss = 0.3178, ratio = 0.90
# iteration = 355/1000, loss = 0.3188, ratio = 0.90
# iteration = 356/1000, loss = 0.3196, ratio = 0.89
# iteration = 357/1000, loss = 0.2908, ratio = 0.93
# iteration = 358/1000, loss = 0.3873, ratio = 0.89
# iteration = 359/1000, loss = 0.3068, ratio = 0.93
# iteration = 360/1000, loss = 0.1995, ratio = 0.92
# iteration = 361/1000, loss = 0.3159, ratio = 0.92
# iteration = 362/1000, loss = 0.1472, ratio = 0.96
# iteration = 363/1000, loss = 0.3918, ratio = 0.89
# iteration = 364/1000, loss = 0.2827, ratio = 0.92
# iteration = 365/1000, loss = 0.3287, ratio = 0.91
# iteration = 366/1000, loss = 0.2807, ratio = 0.91
# iteration = 367/1000, loss = 0.2572, ratio = 0.91
# iteration = 368/1000, loss = 0.3405, ratio = 0.90
# iteration = 369/1000, loss = 0.2533, ratio = 0.92
# iteration = 370/1000, loss = 0.1470, ratio = 0.97
# iteration = 371/1000, loss = 0.3431, ratio = 0.92
# iteration = 372/1000, loss = 0.2855, ratio = 0.93
# iteration = 373/1000, loss = 0.3071, ratio = 0.91
# iteration = 374/1000, loss = 0.3159, ratio = 0.93
# iteration = 375/1000, loss = 0.1773, ratio = 0.95
# iteration = 376/1000, loss = 0.2696, ratio = 0.92
# iteration = 377/1000, loss = 0.3188, ratio = 0.91
# iteration = 378/1000, loss = 0.3369, ratio = 0.90
# iteration = 379/1000, loss = 0.2346, ratio = 0.94
# iteration = 380/1000, loss = 0.2864, ratio = 0.94
# iteration = 381/1000, loss = 0.3811, ratio = 0.87
# iteration = 382/1000, loss = 0.2449, ratio = 0.92
# iteration = 383/1000, loss = 0.4063, ratio = 0.89
# iteration = 384/1000, loss = 0.2398, ratio = 0.93
# iteration = 385/1000, loss = 0.3671, ratio = 0.88
# iteration = 386/1000, loss = 0.2520, ratio = 0.94
# iteration = 387/1000, loss = 0.1551, ratio = 0.97
# iteration = 388/1000, loss = 0.2181, ratio = 0.96
# iteration = 389/1000, loss = 0.2789, ratio = 0.94
# iteration = 390/1000, loss = 0.2712, ratio = 0.95
# iteration = 391/1000, loss = 0.2587, ratio = 0.94
# iteration = 392/1000, loss = 0.2298, ratio = 0.94
# iteration = 393/1000, loss = 0.3014, ratio = 0.91
# iteration = 394/1000, loss = 0.2240, ratio = 0.93
# iteration = 395/1000, loss = 0.3530, ratio = 0.92
# iteration = 396/1000, loss = 0.3210, ratio = 0.91
# iteration = 397/1000, loss = 0.4236, ratio = 0.90
# iteration = 398/1000, loss = 0.1864, ratio = 0.95
# iteration = 399/1000, loss = 0.1545, ratio = 0.95
# iteration = 400/1000, loss = 0.3190, ratio = 0.92
# iteration = 401/1000, loss = 0.3317, ratio = 0.89
# iteration = 402/1000, loss = 0.1793, ratio = 0.96
# iteration = 403/1000, loss = 0.2165, ratio = 0.94
# iteration = 404/1000, loss = 0.2565, ratio = 0.91
# iteration = 405/1000, loss = 0.4034, ratio = 0.89
# iteration = 406/1000, loss = 0.3098, ratio = 0.93
# iteration = 407/1000, loss = 0.4179, ratio = 0.89
# iteration = 408/1000, loss = 0.3612, ratio = 0.89
# iteration = 409/1000, loss = 0.2905, ratio = 0.91
# iteration = 410/1000, loss = 0.2439, ratio = 0.93
# iteration = 411/1000, loss = 0.2313, ratio = 0.92
# iteration = 412/1000, loss = 0.2859, ratio = 0.91
# iteration = 413/1000, loss = 0.2278, ratio = 0.95
# iteration = 414/1000, loss = 0.2537, ratio = 0.92
# iteration = 415/1000, loss = 0.2856, ratio = 0.93
# iteration = 416/1000, loss = 0.2309, ratio = 0.94
# iteration = 417/1000, loss = 0.2854, ratio = 0.92
# iteration = 418/1000, loss = 0.3787, ratio = 0.91
# iteration = 419/1000, loss = 0.2429, ratio = 0.92
# iteration = 420/1000, loss = 0.2882, ratio = 0.93
# iteration = 421/1000, loss = 0.2363, ratio = 0.92
# iteration = 422/1000, loss = 0.1712, ratio = 0.94
# iteration = 423/1000, loss = 0.2342, ratio = 0.96
# iteration = 424/1000, loss = 0.1869, ratio = 0.95
# iteration = 425/1000, loss = 0.1896, ratio = 0.92
# iteration = 426/1000, loss = 0.1751, ratio = 0.97
# iteration = 427/1000, loss = 0.2633, ratio = 0.90
# iteration = 428/1000, loss = 0.2981, ratio = 0.94
# iteration = 429/1000, loss = 0.3649, ratio = 0.92
# iteration = 430/1000, loss = 0.1595, ratio = 0.96
# iteration = 431/1000, loss = 0.3442, ratio = 0.91
# iteration = 432/1000, loss = 0.2697, ratio = 0.93
# iteration = 433/1000, loss = 0.2523, ratio = 0.96
# iteration = 434/1000, loss = 0.2911, ratio = 0.92
# iteration = 435/1000, loss = 0.2655, ratio = 0.94
# iteration = 436/1000, loss = 0.3396, ratio = 0.90
# iteration = 437/1000, loss = 0.4579, ratio = 0.85
# iteration = 438/1000, loss = 0.2224, ratio = 0.94
# iteration = 439/1000, loss = 0.1832, ratio = 0.94
# iteration = 440/1000, loss = 0.2828, ratio = 0.92
# iteration = 441/1000, loss = 0.3053, ratio = 0.88
# iteration = 442/1000, loss = 0.4439, ratio = 0.89
# iteration = 443/1000, loss = 0.2102, ratio = 0.93
# iteration = 444/1000, loss = 0.3148, ratio = 0.88
# iteration = 445/1000, loss = 0.2333, ratio = 0.93
# iteration = 446/1000, loss = 0.3320, ratio = 0.89
# iteration = 447/1000, loss = 0.3835, ratio = 0.90
# iteration = 448/1000, loss = 0.2295, ratio = 0.95
# iteration = 449/1000, loss = 0.2355, ratio = 0.95
# iteration = 450/1000, loss = 0.2251, ratio = 0.96
# iteration = 451/1000, loss = 0.2120, ratio = 0.95
# iteration = 452/1000, loss = 0.2059, ratio = 0.97
# iteration = 453/1000, loss = 0.1967, ratio = 0.96
# iteration = 454/1000, loss = 0.1913, ratio = 0.95
# iteration = 455/1000, loss = 0.1887, ratio = 0.96
# iteration = 456/1000, loss = 0.1583, ratio = 0.95
# iteration = 457/1000, loss = 0.2979, ratio = 0.91
# iteration = 458/1000, loss = 0.2740, ratio = 0.94
# iteration = 459/1000, loss = 0.1994, ratio = 0.95
# iteration = 460/1000, loss = 0.3442, ratio = 0.90
# iteration = 461/1000, loss = 0.3222, ratio = 0.90
# iteration = 462/1000, loss = 0.3717, ratio = 0.90
# iteration = 463/1000, loss = 0.2406, ratio = 0.91
# iteration = 464/1000, loss = 0.4058, ratio = 0.89
# iteration = 465/1000, loss = 0.2360, ratio = 0.94
# iteration = 466/1000, loss = 0.2225, ratio = 0.91
# iteration = 467/1000, loss = 0.2505, ratio = 0.92
# iteration = 468/1000, loss = 0.2191, ratio = 0.95
# iteration = 469/1000, loss = 0.2283, ratio = 0.94
# iteration = 470/1000, loss = 0.2259, ratio = 0.95
# iteration = 471/1000, loss = 0.1182, ratio = 0.98
# iteration = 472/1000, loss = 0.2404, ratio = 0.92
# iteration = 473/1000, loss = 0.1927, ratio = 0.95
# iteration = 474/1000, loss = 0.2846, ratio = 0.91
# iteration = 475/1000, loss = 0.2483, ratio = 0.93
# iteration = 476/1000, loss = 0.3703, ratio = 0.94
# iteration = 477/1000, loss = 0.3080, ratio = 0.90
# iteration = 478/1000, loss = 0.2524, ratio = 0.90
# iteration = 479/1000, loss = 0.2104, ratio = 0.92
# iteration = 480/1000, loss = 0.1304, ratio = 0.97
# iteration = 481/1000, loss = 0.2743, ratio = 0.93
# iteration = 482/1000, loss = 0.2728, ratio = 0.94
# iteration = 483/1000, loss = 0.2669, ratio = 0.93
# iteration = 484/1000, loss = 0.1978, ratio = 0.95
# iteration = 485/1000, loss = 0.3993, ratio = 0.93
# iteration = 486/1000, loss = 0.2668, ratio = 0.93
# iteration = 487/1000, loss = 0.1682, ratio = 0.95
# iteration = 488/1000, loss = 0.3258, ratio = 0.91
# iteration = 489/1000, loss = 0.2664, ratio = 0.94
# iteration = 490/1000, loss = 0.3094, ratio = 0.88
# iteration = 491/1000, loss = 0.2793, ratio = 0.95
# iteration = 492/1000, loss = 0.3535, ratio = 0.90
# iteration = 493/1000, loss = 0.1990, ratio = 0.95
# iteration = 494/1000, loss = 0.4520, ratio = 0.88
# iteration = 495/1000, loss = 0.2381, ratio = 0.91
# iteration = 496/1000, loss = 0.2365, ratio = 0.90
# iteration = 497/1000, loss = 0.2621, ratio = 0.91
# iteration = 498/1000, loss = 0.2655, ratio = 0.90
# iteration = 499/1000, loss = 0.2604, ratio = 0.96
# iteration = 500/1000, loss = 0.1805, ratio = 0.94
# iteration = 501/1000, loss = 0.5049, ratio = 0.89
# iteration = 502/1000, loss = 0.2001, ratio = 0.96
# iteration = 503/1000, loss = 0.1965, ratio = 0.96
# iteration = 504/1000, loss = 0.3032, ratio = 0.92
# iteration = 505/1000, loss = 0.4092, ratio = 0.88
# iteration = 506/1000, loss = 0.2733, ratio = 0.94
# iteration = 507/1000, loss = 0.3322, ratio = 0.92
# iteration = 508/1000, loss = 0.2325, ratio = 0.94
# iteration = 509/1000, loss = 0.2850, ratio = 0.93
# iteration = 510/1000, loss = 0.1141, ratio = 0.98
# iteration = 511/1000, loss = 0.1618, ratio = 0.94
# iteration = 512/1000, loss = 0.2641, ratio = 0.94
# iteration = 513/1000, loss = 0.1766, ratio = 0.94
# iteration = 514/1000, loss = 0.3043, ratio = 0.93
# iteration = 515/1000, loss = 0.2661, ratio = 0.92
# iteration = 516/1000, loss = 0.3562, ratio = 0.85
# iteration = 517/1000, loss = 0.3144, ratio = 0.91
# iteration = 518/1000, loss = 0.3801, ratio = 0.88
# iteration = 519/1000, loss = 0.2814, ratio = 0.93
# iteration = 520/1000, loss = 0.2166, ratio = 0.92
# iteration = 521/1000, loss = 0.2463, ratio = 0.92
# iteration = 522/1000, loss = 0.3259, ratio = 0.90
# iteration = 523/1000, loss = 0.2761, ratio = 0.90
# iteration = 524/1000, loss = 0.2266, ratio = 0.95
# iteration = 525/1000, loss = 0.1847, ratio = 0.96
# iteration = 526/1000, loss = 0.2450, ratio = 0.93
# iteration = 527/1000, loss = 0.2127, ratio = 0.95
# iteration = 528/1000, loss = 0.2531, ratio = 0.93
# iteration = 529/1000, loss = 0.2458, ratio = 0.91
# iteration = 530/1000, loss = 0.3309, ratio = 0.90
# iteration = 531/1000, loss = 0.1935, ratio = 0.91
# iteration = 532/1000, loss = 0.1875, ratio = 0.94
# iteration = 533/1000, loss = 0.1919, ratio = 0.94
# iteration = 534/1000, loss = 0.2639, ratio = 0.94
# iteration = 535/1000, loss = 0.2476, ratio = 0.92
# iteration = 536/1000, loss = 0.1948, ratio = 0.94
# iteration = 537/1000, loss = 0.2894, ratio = 0.91
# iteration = 538/1000, loss = 0.2327, ratio = 0.92
# iteration = 539/1000, loss = 0.3149, ratio = 0.90
# iteration = 540/1000, loss = 0.3118, ratio = 0.92
# iteration = 541/1000, loss = 0.3052, ratio = 0.94
# iteration = 542/1000, loss = 0.1951, ratio = 0.95
# iteration = 543/1000, loss = 0.3725, ratio = 0.92
# iteration = 544/1000, loss = 0.2377, ratio = 0.91
# iteration = 545/1000, loss = 0.2709, ratio = 0.90
# iteration = 546/1000, loss = 0.2751, ratio = 0.91
# iteration = 547/1000, loss = 0.2856, ratio = 0.89
# iteration = 548/1000, loss = 0.2862, ratio = 0.92
# iteration = 549/1000, loss = 0.2048, ratio = 0.95
# iteration = 550/1000, loss = 0.3316, ratio = 0.94
# iteration = 551/1000, loss = 0.1913, ratio = 0.95
# iteration = 552/1000, loss = 0.2296, ratio = 0.93
# iteration = 553/1000, loss = 0.3843, ratio = 0.88
# iteration = 554/1000, loss = 0.2487, ratio = 0.94
# iteration = 555/1000, loss = 0.2139, ratio = 0.95
# iteration = 556/1000, loss = 0.2140, ratio = 0.93
# iteration = 557/1000, loss = 0.2056, ratio = 0.95
# iteration = 558/1000, loss = 0.1576, ratio = 0.97
# iteration = 559/1000, loss = 0.2642, ratio = 0.90
# iteration = 560/1000, loss = 0.3870, ratio = 0.90
# iteration = 561/1000, loss = 0.3132, ratio = 0.92
# iteration = 562/1000, loss = 0.2148, ratio = 0.92
# iteration = 563/1000, loss = 0.2225, ratio = 0.93
# iteration = 564/1000, loss = 0.2010, ratio = 0.95
# iteration = 565/1000, loss = 0.3532, ratio = 0.91
# iteration = 566/1000, loss = 0.2545, ratio = 0.91
# iteration = 567/1000, loss = 0.1714, ratio = 0.96
# iteration = 568/1000, loss = 0.1326, ratio = 0.98
# iteration = 569/1000, loss = 0.3153, ratio = 0.91
# iteration = 570/1000, loss = 0.4904, ratio = 0.84
# iteration = 571/1000, loss = 0.1406, ratio = 0.96
# iteration = 572/1000, loss = 0.2474, ratio = 0.94
# iteration = 573/1000, loss = 0.2771, ratio = 0.93
# iteration = 574/1000, loss = 0.2750, ratio = 0.94
# iteration = 575/1000, loss = 0.1502, ratio = 0.96
# iteration = 576/1000, loss = 0.3015, ratio = 0.91
# iteration = 577/1000, loss = 0.3463, ratio = 0.89
# iteration = 578/1000, loss = 0.2272, ratio = 0.95
# iteration = 579/1000, loss = 0.2543, ratio = 0.94
# iteration = 580/1000, loss = 0.3021, ratio = 0.94
# iteration = 581/1000, loss = 0.2417, ratio = 0.92
# iteration = 582/1000, loss = 0.3543, ratio = 0.88
# iteration = 583/1000, loss = 0.4219, ratio = 0.87
# iteration = 584/1000, loss = 0.2817, ratio = 0.90
# iteration = 585/1000, loss = 0.1278, ratio = 0.97
# iteration = 586/1000, loss = 0.2975, ratio = 0.92
# iteration = 587/1000, loss = 0.2473, ratio = 0.97
# iteration = 588/1000, loss = 0.3097, ratio = 0.92
# iteration = 589/1000, loss = 0.2200, ratio = 0.94
# iteration = 590/1000, loss = 0.2389, ratio = 0.94
# iteration = 591/1000, loss = 0.2753, ratio = 0.90
# iteration = 592/1000, loss = 0.2218, ratio = 0.94
# iteration = 593/1000, loss = 0.2274, ratio = 0.94
# iteration = 594/1000, loss = 0.2513, ratio = 0.91
# iteration = 595/1000, loss = 0.4171, ratio = 0.92
# iteration = 596/1000, loss = 0.1140, ratio = 0.98
# iteration = 597/1000, loss = 0.1509, ratio = 0.96
# iteration = 598/1000, loss = 0.2776, ratio = 0.93
# iteration = 599/1000, loss = 0.2799, ratio = 0.93
# iteration = 600/1000, loss = 0.1518, ratio = 0.96
# iteration = 601/1000, loss = 0.2754, ratio = 0.91
# iteration = 602/1000, loss = 0.2537, ratio = 0.90
# iteration = 603/1000, loss = 0.1956, ratio = 0.93
# iteration = 604/1000, loss = 0.1505, ratio = 0.95
# iteration = 605/1000, loss = 0.1735, ratio = 0.92
# iteration = 606/1000, loss = 0.1942, ratio = 0.92
# iteration = 607/1000, loss = 0.1544, ratio = 0.98
# iteration = 608/1000, loss = 0.2189, ratio = 0.92
# iteration = 609/1000, loss = 0.1337, ratio = 0.97
# iteration = 610/1000, loss = 0.2809, ratio = 0.91
# iteration = 611/1000, loss = 0.2830, ratio = 0.92
# iteration = 612/1000, loss = 0.0801, ratio = 0.98
# iteration = 613/1000, loss = 0.2420, ratio = 0.90
# iteration = 614/1000, loss = 0.1974, ratio = 0.95
# iteration = 615/1000, loss = 0.3223, ratio = 0.91
# iteration = 616/1000, loss = 0.2717, ratio = 0.90
# iteration = 617/1000, loss = 0.1742, ratio = 0.95
# iteration = 618/1000, loss = 0.1426, ratio = 0.93
# iteration = 619/1000, loss = 0.2037, ratio = 0.92
# iteration = 620/1000, loss = 0.1957, ratio = 0.95
# iteration = 621/1000, loss = 0.3200, ratio = 0.93
# iteration = 622/1000, loss = 0.1721, ratio = 0.94
# iteration = 623/1000, loss = 0.2902, ratio = 0.94
# iteration = 624/1000, loss = 0.2277, ratio = 0.96
# iteration = 625/1000, loss = 0.1367, ratio = 0.98
# iteration = 626/1000, loss = 0.1313, ratio = 0.97
# iteration = 627/1000, loss = 0.2383, ratio = 0.93
# iteration = 628/1000, loss = 0.2572, ratio = 0.92
# iteration = 629/1000, loss = 0.2819, ratio = 0.91
# iteration = 630/1000, loss = 0.2936, ratio = 0.93
# iteration = 631/1000, loss = 0.2542, ratio = 0.92
# iteration = 632/1000, loss = 0.2176, ratio = 0.92
# iteration = 633/1000, loss = 0.2128, ratio = 0.97
# iteration = 634/1000, loss = 0.3301, ratio = 0.89
# iteration = 635/1000, loss = 0.1011, ratio = 0.98
# iteration = 636/1000, loss = 0.2241, ratio = 0.95
# iteration = 637/1000, loss = 0.2188, ratio = 0.93
# iteration = 638/1000, loss = 0.2840, ratio = 0.94
# iteration = 639/1000, loss = 0.1923, ratio = 0.94
# iteration = 640/1000, loss = 0.2570, ratio = 0.89
# iteration = 641/1000, loss = 0.3121, ratio = 0.90
# iteration = 642/1000, loss = 0.1954, ratio = 0.95
# iteration = 643/1000, loss = 0.3222, ratio = 0.90
# iteration = 644/1000, loss = 0.3034, ratio = 0.92
# iteration = 645/1000, loss = 0.1230, ratio = 0.98
# iteration = 646/1000, loss = 0.2100, ratio = 0.92
# iteration = 647/1000, loss = 0.2524, ratio = 0.89
# iteration = 648/1000, loss = 0.2806, ratio = 0.92
# iteration = 649/1000, loss = 0.3120, ratio = 0.90
# iteration = 650/1000, loss = 0.3203, ratio = 0.94
# iteration = 651/1000, loss = 0.2373, ratio = 0.92
# iteration = 652/1000, loss = 0.2764, ratio = 0.92
# iteration = 653/1000, loss = 0.1614, ratio = 0.94
# iteration = 654/1000, loss = 0.1693, ratio = 0.95
# iteration = 655/1000, loss = 0.1678, ratio = 0.96
# iteration = 656/1000, loss = 0.2670, ratio = 0.93
# iteration = 657/1000, loss = 0.3463, ratio = 0.90
# iteration = 658/1000, loss = 0.2775, ratio = 0.93
# iteration = 659/1000, loss = 0.2130, ratio = 0.94
# iteration = 660/1000, loss = 0.3800, ratio = 0.89
# iteration = 661/1000, loss = 0.2471, ratio = 0.91
# iteration = 662/1000, loss = 0.1933, ratio = 0.93
# iteration = 663/1000, loss = 0.1806, ratio = 0.95
# iteration = 664/1000, loss = 0.1838, ratio = 0.93
# iteration = 665/1000, loss = 0.2701, ratio = 0.94
# iteration = 666/1000, loss = 0.2865, ratio = 0.90
# iteration = 667/1000, loss = 0.2581, ratio = 0.94
# iteration = 668/1000, loss = 0.2784, ratio = 0.92
# iteration = 669/1000, loss = 0.4163, ratio = 0.88
# iteration = 670/1000, loss = 0.2887, ratio = 0.93
# iteration = 671/1000, loss = 0.2979, ratio = 0.91
# iteration = 672/1000, loss = 0.1885, ratio = 0.96
# iteration = 673/1000, loss = 0.2586, ratio = 0.92
# iteration = 674/1000, loss = 0.2379, ratio = 0.96
# iteration = 675/1000, loss = 0.2590, ratio = 0.94
# iteration = 676/1000, loss = 0.2985, ratio = 0.92
# iteration = 677/1000, loss = 0.3151, ratio = 0.92
# iteration = 678/1000, loss = 0.1890, ratio = 0.94
# iteration = 679/1000, loss = 0.2228, ratio = 0.96
# iteration = 680/1000, loss = 0.2903, ratio = 0.92
# iteration = 681/1000, loss = 0.1963, ratio = 0.94
# iteration = 682/1000, loss = 0.3337, ratio = 0.90
# iteration = 683/1000, loss = 0.2920, ratio = 0.91
# iteration = 684/1000, loss = 0.0892, ratio = 0.99
# iteration = 685/1000, loss = 0.2407, ratio = 0.90
# iteration = 686/1000, loss = 0.4662, ratio = 0.89
# iteration = 687/1000, loss = 0.3167, ratio = 0.91
# iteration = 688/1000, loss = 0.3298, ratio = 0.94
# iteration = 689/1000, loss = 0.2371, ratio = 0.94
# iteration = 690/1000, loss = 0.2410, ratio = 0.94
# iteration = 691/1000, loss = 0.2414, ratio = 0.92
# iteration = 692/1000, loss = 0.3758, ratio = 0.88
# iteration = 693/1000, loss = 0.3182, ratio = 0.91
# iteration = 694/1000, loss = 0.3312, ratio = 0.91
# iteration = 695/1000, loss = 0.2261, ratio = 0.92
# iteration = 696/1000, loss = 0.1358, ratio = 0.95
# iteration = 697/1000, loss = 0.2525, ratio = 0.95
# iteration = 698/1000, loss = 0.2438, ratio = 0.92
# iteration = 699/1000, loss = 0.2429, ratio = 0.93
# iteration = 700/1000, loss = 0.1678, ratio = 0.97
# iteration = 701/1000, loss = 0.1951, ratio = 0.94
# iteration = 702/1000, loss = 0.2860, ratio = 0.92
# iteration = 703/1000, loss = 0.1974, ratio = 0.94
# iteration = 704/1000, loss = 0.1873, ratio = 0.94
# iteration = 705/1000, loss = 0.3329, ratio = 0.89
# iteration = 706/1000, loss = 0.1507, ratio = 0.96
# iteration = 707/1000, loss = 0.2016, ratio = 0.94
# iteration = 708/1000, loss = 0.2680, ratio = 0.92
# iteration = 709/1000, loss = 0.2017, ratio = 0.94
# iteration = 710/1000, loss = 0.3514, ratio = 0.92
# iteration = 711/1000, loss = 0.2483, ratio = 0.94
# iteration = 712/1000, loss = 0.3307, ratio = 0.93
# iteration = 713/1000, loss = 0.2296, ratio = 0.93
# iteration = 714/1000, loss = 0.2700, ratio = 0.87
# iteration = 715/1000, loss = 0.2664, ratio = 0.90
# iteration = 716/1000, loss = 0.2020, ratio = 0.93
# iteration = 717/1000, loss = 0.1735, ratio = 0.95
# iteration = 718/1000, loss = 0.1530, ratio = 0.96
# iteration = 719/1000, loss = 0.2860, ratio = 0.94
# iteration = 720/1000, loss = 0.1648, ratio = 0.96
# iteration = 721/1000, loss = 0.2119, ratio = 0.94
# iteration = 722/1000, loss = 0.3082, ratio = 0.90
# iteration = 723/1000, loss = 0.1366, ratio = 0.97
# iteration = 724/1000, loss = 0.1942, ratio = 0.93
# iteration = 725/1000, loss = 0.2422, ratio = 0.93
# iteration = 726/1000, loss = 0.2973, ratio = 0.93
# iteration = 727/1000, loss = 0.1678, ratio = 0.96
# iteration = 728/1000, loss = 0.2922, ratio = 0.93
# iteration = 729/1000, loss = 0.2450, ratio = 0.94
# iteration = 730/1000, loss = 0.3154, ratio = 0.90
# iteration = 731/1000, loss = 0.1711, ratio = 0.95
# iteration = 732/1000, loss = 0.2505, ratio = 0.92
# iteration = 733/1000, loss = 0.2196, ratio = 0.96
# iteration = 734/1000, loss = 0.2795, ratio = 0.94
# iteration = 735/1000, loss = 0.2283, ratio = 0.93
# iteration = 736/1000, loss = 0.2424, ratio = 0.89
# iteration = 737/1000, loss = 0.2662, ratio = 0.93
# iteration = 738/1000, loss = 0.1633, ratio = 0.97
# iteration = 739/1000, loss = 0.3115, ratio = 0.92
# iteration = 740/1000, loss = 0.1799, ratio = 0.93
# iteration = 741/1000, loss = 0.1980, ratio = 0.93
# iteration = 742/1000, loss = 0.1693, ratio = 0.96
# iteration = 743/1000, loss = 0.2418, ratio = 0.92
# iteration = 744/1000, loss = 0.1661, ratio = 0.96
# iteration = 745/1000, loss = 0.2860, ratio = 0.92
# iteration = 746/1000, loss = 0.2802, ratio = 0.91
# iteration = 747/1000, loss = 0.2386, ratio = 0.95
# iteration = 748/1000, loss = 0.2760, ratio = 0.92
# iteration = 749/1000, loss = 0.2204, ratio = 0.93
# iteration = 750/1000, loss = 0.1905, ratio = 0.91
# iteration = 751/1000, loss = 0.1357, ratio = 0.97
# iteration = 752/1000, loss = 0.1608, ratio = 0.96
# iteration = 753/1000, loss = 0.2928, ratio = 0.91
# iteration = 754/1000, loss = 0.2050, ratio = 0.94
# iteration = 755/1000, loss = 0.1606, ratio = 0.99
# iteration = 756/1000, loss = 0.2161, ratio = 0.94
# iteration = 757/1000, loss = 0.1141, ratio = 0.95
# iteration = 758/1000, loss = 0.2308, ratio = 0.93
# iteration = 759/1000, loss = 0.1615, ratio = 0.93
# iteration = 760/1000, loss = 0.2840, ratio = 0.94
# iteration = 761/1000, loss = 0.1893, ratio = 0.95
# iteration = 762/1000, loss = 0.1928, ratio = 0.94
# iteration = 763/1000, loss = 0.1600, ratio = 0.94
# iteration = 764/1000, loss = 0.1984, ratio = 0.93
# iteration = 765/1000, loss = 0.1926, ratio = 0.94
# iteration = 766/1000, loss = 0.2760, ratio = 0.91
# iteration = 767/1000, loss = 0.1934, ratio = 0.96
# iteration = 768/1000, loss = 0.2833, ratio = 0.94
# iteration = 769/1000, loss = 0.2070, ratio = 0.96
# iteration = 770/1000, loss = 0.3041, ratio = 0.92
# iteration = 771/1000, loss = 0.2216, ratio = 0.95
# iteration = 772/1000, loss = 0.1767, ratio = 0.96
# iteration = 773/1000, loss = 0.4105, ratio = 0.93
# iteration = 774/1000, loss = 0.3014, ratio = 0.93
# iteration = 775/1000, loss = 0.1639, ratio = 0.93
# iteration = 776/1000, loss = 0.1866, ratio = 0.93
# iteration = 777/1000, loss = 0.1708, ratio = 0.95
# iteration = 778/1000, loss = 0.3176, ratio = 0.91
# iteration = 779/1000, loss = 0.2730, ratio = 0.93
# iteration = 780/1000, loss = 0.3832, ratio = 0.91
# iteration = 781/1000, loss = 0.2608, ratio = 0.92
# iteration = 782/1000, loss = 0.2137, ratio = 0.93
# iteration = 783/1000, loss = 0.1407, ratio = 0.96
# iteration = 784/1000, loss = 0.2764, ratio = 0.94
# iteration = 785/1000, loss = 0.1989, ratio = 0.93
# iteration = 786/1000, loss = 0.1942, ratio = 0.93
# iteration = 787/1000, loss = 0.3342, ratio = 0.90
# iteration = 788/1000, loss = 0.2899, ratio = 0.91
# iteration = 789/1000, loss = 0.2779, ratio = 0.92
# iteration = 790/1000, loss = 0.3806, ratio = 0.87
# iteration = 791/1000, loss = 0.3107, ratio = 0.90
# iteration = 792/1000, loss = 0.2316, ratio = 0.92
# iteration = 793/1000, loss = 0.2945, ratio = 0.88
# iteration = 794/1000, loss = 0.1678, ratio = 0.96
# iteration = 795/1000, loss = 0.1782, ratio = 0.97
# iteration = 796/1000, loss = 0.2146, ratio = 0.92
# iteration = 797/1000, loss = 0.1774, ratio = 0.94
# iteration = 798/1000, loss = 0.2011, ratio = 0.93
# iteration = 799/1000, loss = 0.1801, ratio = 0.94
# iteration = 800/1000, loss = 0.2132, ratio = 0.94
# iteration = 801/1000, loss = 0.2677, ratio = 0.94
# iteration = 802/1000, loss = 0.1321, ratio = 0.98
# iteration = 803/1000, loss = 0.3198, ratio = 0.92
# iteration = 804/1000, loss = 0.1919, ratio = 0.94
# iteration = 805/1000, loss = 0.2070, ratio = 0.93
# iteration = 806/1000, loss = 0.1817, ratio = 0.96
# iteration = 807/1000, loss = 0.2913, ratio = 0.88
# iteration = 808/1000, loss = 0.2158, ratio = 0.95
# iteration = 809/1000, loss = 0.2291, ratio = 0.91
# iteration = 810/1000, loss = 0.1196, ratio = 0.97
# iteration = 811/1000, loss = 0.2020, ratio = 0.95
# iteration = 812/1000, loss = 0.1623, ratio = 0.96
# iteration = 813/1000, loss = 0.3347, ratio = 0.89
# iteration = 814/1000, loss = 0.2608, ratio = 0.93
# iteration = 815/1000, loss = 0.2811, ratio = 0.92
# iteration = 816/1000, loss = 0.2607, ratio = 0.92
# iteration = 817/1000, loss = 0.1839, ratio = 0.94
# iteration = 818/1000, loss = 0.2175, ratio = 0.95
# iteration = 819/1000, loss = 0.1433, ratio = 0.96
# iteration = 820/1000, loss = 0.2634, ratio = 0.92
# iteration = 821/1000, loss = 0.3494, ratio = 0.91
# iteration = 822/1000, loss = 0.2961, ratio = 0.94
# iteration = 823/1000, loss = 0.1976, ratio = 0.93
# iteration = 824/1000, loss = 0.1715, ratio = 0.96
# iteration = 825/1000, loss = 0.1257, ratio = 0.98
# iteration = 826/1000, loss = 0.2022, ratio = 0.95
# iteration = 827/1000, loss = 0.2092, ratio = 0.94
# iteration = 828/1000, loss = 0.1918, ratio = 0.93
# iteration = 829/1000, loss = 0.1507, ratio = 0.97
# iteration = 830/1000, loss = 0.2610, ratio = 0.93
# iteration = 831/1000, loss = 0.1982, ratio = 0.94
# iteration = 832/1000, loss = 0.3819, ratio = 0.89
# iteration = 833/1000, loss = 0.2434, ratio = 0.90
# iteration = 834/1000, loss = 0.2460, ratio = 0.90
# iteration = 835/1000, loss = 0.1338, ratio = 0.97
# iteration = 836/1000, loss = 0.2266, ratio = 0.91
# iteration = 837/1000, loss = 0.1765, ratio = 0.94
# iteration = 838/1000, loss = 0.2645, ratio = 0.91
# iteration = 839/1000, loss = 0.1232, ratio = 0.97
# iteration = 840/1000, loss = 0.2175, ratio = 0.94
# iteration = 841/1000, loss = 0.2842, ratio = 0.91
# iteration = 842/1000, loss = 0.2600, ratio = 0.93
# iteration = 843/1000, loss = 0.2046, ratio = 0.95
# iteration = 844/1000, loss = 0.3308, ratio = 0.90
# iteration = 845/1000, loss = 0.2845, ratio = 0.91
# iteration = 846/1000, loss = 0.3141, ratio = 0.90
# iteration = 847/1000, loss = 0.1431, ratio = 0.95
# iteration = 848/1000, loss = 0.1786, ratio = 0.95
# iteration = 849/1000, loss = 0.2606, ratio = 0.92
# iteration = 850/1000, loss = 0.2481, ratio = 0.93
# iteration = 851/1000, loss = 0.2428, ratio = 0.91
# iteration = 852/1000, loss = 0.2228, ratio = 0.96
# iteration = 853/1000, loss = 0.2723, ratio = 0.93
# iteration = 854/1000, loss = 0.3025, ratio = 0.92
# iteration = 855/1000, loss = 0.2614, ratio = 0.92
# iteration = 856/1000, loss = 0.2591, ratio = 0.93
# iteration = 857/1000, loss = 0.2454, ratio = 0.94
# iteration = 858/1000, loss = 0.3199, ratio = 0.91
# iteration = 859/1000, loss = 0.3125, ratio = 0.93
# iteration = 860/1000, loss = 0.1759, ratio = 0.93
# iteration = 861/1000, loss = 0.3076, ratio = 0.92
# iteration = 862/1000, loss = 0.1870, ratio = 0.95
# iteration = 863/1000, loss = 0.2630, ratio = 0.95
# iteration = 864/1000, loss = 0.1118, ratio = 0.98
# iteration = 865/1000, loss = 0.2840, ratio = 0.90
# iteration = 866/1000, loss = 0.2546, ratio = 0.93
# iteration = 867/1000, loss = 0.3654, ratio = 0.92
# iteration = 868/1000, loss = 0.1559, ratio = 0.94
# iteration = 869/1000, loss = 0.2810, ratio = 0.94
# iteration = 870/1000, loss = 0.2058, ratio = 0.96
# iteration = 871/1000, loss = 0.1820, ratio = 0.92
# iteration = 872/1000, loss = 0.3048, ratio = 0.89
# iteration = 873/1000, loss = 0.1782, ratio = 0.95
# iteration = 874/1000, loss = 0.1966, ratio = 0.95
# iteration = 875/1000, loss = 0.2982, ratio = 0.95
# iteration = 876/1000, loss = 0.1284, ratio = 0.97
# iteration = 877/1000, loss = 0.1585, ratio = 0.95
# iteration = 878/1000, loss = 0.2373, ratio = 0.94
# iteration = 879/1000, loss = 0.2754, ratio = 0.90
# iteration = 880/1000, loss = 0.2402, ratio = 0.95
# iteration = 881/1000, loss = 0.1559, ratio = 0.98
# iteration = 882/1000, loss = 0.2907, ratio = 0.87
# iteration = 883/1000, loss = 0.2419, ratio = 0.93
# iteration = 884/1000, loss = 0.1761, ratio = 0.96
# iteration = 885/1000, loss = 0.2257, ratio = 0.91
# iteration = 886/1000, loss = 0.2204, ratio = 0.95
# iteration = 887/1000, loss = 0.2931, ratio = 0.92
# iteration = 888/1000, loss = 0.2633, ratio = 0.94
# iteration = 889/1000, loss = 0.3412, ratio = 0.91
# iteration = 890/1000, loss = 0.1953, ratio = 0.94
# iteration = 891/1000, loss = 0.1945, ratio = 0.97
# iteration = 892/1000, loss = 0.2665, ratio = 0.91
# iteration = 893/1000, loss = 0.2710, ratio = 0.94
# iteration = 894/1000, loss = 0.1608, ratio = 0.97
# iteration = 895/1000, loss = 0.1473, ratio = 0.96
# iteration = 896/1000, loss = 0.1995, ratio = 0.94
# iteration = 897/1000, loss = 0.2091, ratio = 0.97
# iteration = 898/1000, loss = 0.2449, ratio = 0.93
# iteration = 899/1000, loss = 0.2057, ratio = 0.93
# iteration = 900/1000, loss = 0.2272, ratio = 0.93
# iteration = 901/1000, loss = 0.2912, ratio = 0.92
# iteration = 902/1000, loss = 0.2104, ratio = 0.93
# iteration = 903/1000, loss = 0.2038, ratio = 0.95
# iteration = 904/1000, loss = 0.1512, ratio = 0.96
# iteration = 905/1000, loss = 0.2142, ratio = 0.92
# iteration = 906/1000, loss = 0.3107, ratio = 0.92
# iteration = 907/1000, loss = 0.3448, ratio = 0.92
# iteration = 908/1000, loss = 0.2098, ratio = 0.95
# iteration = 909/1000, loss = 0.2449, ratio = 0.92
# iteration = 910/1000, loss = 0.1943, ratio = 0.95
# iteration = 911/1000, loss = 0.2511, ratio = 0.91
# iteration = 912/1000, loss = 0.3254, ratio = 0.91
# iteration = 913/1000, loss = 0.2197, ratio = 0.93
# iteration = 914/1000, loss = 0.3162, ratio = 0.93
# iteration = 915/1000, loss = 0.2515, ratio = 0.93
# iteration = 916/1000, loss = 0.2838, ratio = 0.91
# iteration = 917/1000, loss = 0.3496, ratio = 0.88
# iteration = 918/1000, loss = 0.2012, ratio = 0.95
# iteration = 919/1000, loss = 0.2203, ratio = 0.92
# iteration = 920/1000, loss = 0.1276, ratio = 0.96
# iteration = 921/1000, loss = 0.2840, ratio = 0.90
# iteration = 922/1000, loss = 0.1809, ratio = 0.92
# iteration = 923/1000, loss = 0.1566, ratio = 0.95
# iteration = 924/1000, loss = 0.2110, ratio = 0.95
# iteration = 925/1000, loss = 0.2556, ratio = 0.96
# iteration = 926/1000, loss = 0.2154, ratio = 0.95
# iteration = 927/1000, loss = 0.3578, ratio = 0.92
# iteration = 928/1000, loss = 0.2283, ratio = 0.92
# iteration = 929/1000, loss = 0.1614, ratio = 0.96
# iteration = 930/1000, loss = 0.2287, ratio = 0.92
# iteration = 931/1000, loss = 0.2532, ratio = 0.93
# iteration = 932/1000, loss = 0.2585, ratio = 0.95
# iteration = 933/1000, loss = 0.2703, ratio = 0.90
# iteration = 934/1000, loss = 0.2594, ratio = 0.94
# iteration = 935/1000, loss = 0.2043, ratio = 0.94
# iteration = 936/1000, loss = 0.1988, ratio = 0.94
# iteration = 937/1000, loss = 0.4586, ratio = 0.87
# iteration = 938/1000, loss = 0.2512, ratio = 0.93
# iteration = 939/1000, loss = 0.1972, ratio = 0.93
# iteration = 940/1000, loss = 0.1705, ratio = 0.94
# iteration = 941/1000, loss = 0.1410, ratio = 0.96
# iteration = 942/1000, loss = 0.1438, ratio = 0.96
# iteration = 943/1000, loss = 0.3003, ratio = 0.91
# iteration = 944/1000, loss = 0.2617, ratio = 0.95
# iteration = 945/1000, loss = 0.2566, ratio = 0.93
# iteration = 946/1000, loss = 0.2144, ratio = 0.94
# iteration = 947/1000, loss = 0.2213, ratio = 0.95
# iteration = 948/1000, loss = 0.1131, ratio = 0.98
# iteration = 949/1000, loss = 0.2444, ratio = 0.91
# iteration = 950/1000, loss = 0.2000, ratio = 0.95
# iteration = 951/1000, loss = 0.1940, ratio = 0.93
# iteration = 952/1000, loss = 0.3628, ratio = 0.87
# iteration = 953/1000, loss = 0.2510, ratio = 0.92
# iteration = 954/1000, loss = 0.2378, ratio = 0.91
# iteration = 955/1000, loss = 0.2402, ratio = 0.96
# iteration = 956/1000, loss = 0.1429, ratio = 0.95
# iteration = 957/1000, loss = 0.1858, ratio = 0.94
# iteration = 958/1000, loss = 0.2006, ratio = 0.93
# iteration = 959/1000, loss = 0.4280, ratio = 0.90
# iteration = 960/1000, loss = 0.2217, ratio = 0.94
# iteration = 961/1000, loss = 0.1463, ratio = 0.98
# iteration = 962/1000, loss = 0.3360, ratio = 0.90
# iteration = 963/1000, loss = 0.3891, ratio = 0.91
# iteration = 964/1000, loss = 0.2652, ratio = 0.96
# iteration = 965/1000, loss = 0.2376, ratio = 0.95
# iteration = 966/1000, loss = 0.2692, ratio = 0.90
# iteration = 967/1000, loss = 0.1048, ratio = 0.98
# iteration = 968/1000, loss = 0.2172, ratio = 0.95
# iteration = 969/1000, loss = 0.1888, ratio = 0.94
# iteration = 970/1000, loss = 0.2618, ratio = 0.92
# iteration = 971/1000, loss = 0.4449, ratio = 0.88
# iteration = 972/1000, loss = 0.2179, ratio = 0.94
# iteration = 973/1000, loss = 0.2181, ratio = 0.93
# iteration = 974/1000, loss = 0.2578, ratio = 0.95
# iteration = 975/1000, loss = 0.1776, ratio = 0.95
# iteration = 976/1000, loss = 0.3591, ratio = 0.89
# iteration = 977/1000, loss = 0.2663, ratio = 0.91
# iteration = 978/1000, loss = 0.2435, ratio = 0.92
# iteration = 979/1000, loss = 0.2431, ratio = 0.93
# iteration = 980/1000, loss = 0.3115, ratio = 0.93
# iteration = 981/1000, loss = 0.1267, ratio = 0.94
# iteration = 982/1000, loss = 0.1598, ratio = 0.97
# iteration = 983/1000, loss = 0.1836, ratio = 0.94
# iteration = 984/1000, loss = 0.3461, ratio = 0.89
# iteration = 985/1000, loss = 0.1557, ratio = 0.95
# iteration = 986/1000, loss = 0.1502, ratio = 0.98
# iteration = 987/1000, loss = 0.2275, ratio = 0.90
# iteration = 988/1000, loss = 0.2164, ratio = 0.94
# iteration = 989/1000, loss = 0.2133, ratio = 0.93
# iteration = 990/1000, loss = 0.2139, ratio = 0.96
# iteration = 991/1000, loss = 0.1246, ratio = 0.96
# iteration = 992/1000, loss = 0.3042, ratio = 0.91
# iteration = 993/1000, loss = 0.1899, ratio = 0.94
# iteration = 994/1000, loss = 0.2308, ratio = 0.94
# iteration = 995/1000, loss = 0.1615, ratio = 0.94
# iteration = 996/1000, loss = 0.1498, ratio = 0.96
# iteration = 997/1000, loss = 0.2333, ratio = 0.94
# iteration = 998/1000, loss = 0.1970, ratio = 0.95
# iteration = 999/1000, loss = 0.2276, ratio = 0.92
# Test loss = 0.2647, ratio = 0.919
